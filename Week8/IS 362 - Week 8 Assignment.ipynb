# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # 1. Load the data in the (yellow highlighted) Data Folder in the file auto-mpg.data into a pandas DataFrame.

# %%
df = pd.read_fwf('https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data', header=None)

# %% [markdown]
# # 2. Review the data and the provided data set description.

# %%
df
# Out:
#         0  1      2      3       4     5   6  7  \
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1
# 5    15.0  8  429.0  198.0  4341.0  10.0  70  1
# 6    14.0  8  454.0  220.0  4354.0   9.0  70  1
# 7    14.0  8  440.0  215.0  4312.0   8.5  70  1
# 8    14.0  8  455.0  225.0  4425.0  10.0  70  1
# 9    15.0  8  390.0  190.0  3850.0   8.5  70  1
# 10   15.0  8  383.0  170.0  3563.0  10.0  70  1
# 11   14.0  8  340.0  160.0  3609.0   8.0  70  1
# 12   15.0  8  400.0  150.0  3761.0   9.5  70  1
# 13   14.0  8  455.0  225.0  3086.0  10.0  70  1
# 14   24.0  4  113.0  95.00  2372.0  15.0  70  3
# 15   22.0  6  198.0  95.00  2833.0  15.5  70  1
# 16   18.0  6  199.0  97.00  2774.0  15.5  70  1
# 17   21.0  6  200.0  85.00  2587.0  16.0  70  1
# ...

# %% [markdown]
# # 3. Use the attribute information provided in auto-mpg.names to name your pandas DataFrame columns.

# %%
column_name = ['mpg',
          'cylinders',
          'displacement',
          'horsepower',
          'weight',
          'acceleration',
          'model_year',
          'origin',
          'car_name']
df.columns = column_name
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# 5    15.0          8         429.0      198.0  4341.0          10.0
# 6    14.0          8         454.0      220.0  4354.0           9.0
# 7    14.0          8         440.0      215.0  4312.0           8.5
# 8    14.0          8         455.0      225.0  4425.0          10.0
# 9    15.0          8         390.0      190.0  3850.0           8.5
# 10   15.0          8         383.0      170.0  3563.0          10.0
# 11   14.0          8         340.0      160.0  3609.0           8.0
# 12   15.0          8         400.0      150.0  3761.0           9.5
# ...

# %% [markdown]
# # 4. Some of the horsepower data is marked as missing with a ‘?’. You need to replace this ‘?’ with a pandas-appropriate missing value, then convert the column to numeric.

# %%
df.replace('?', np.NaN)
df.horsepower = pd.to_numeric(df.horsepower, errors = 'err')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# 5    15.0          8         429.0       198.0  4341.0          10.0
# 6    14.0          8         454.0       220.0  4354.0           9.0
# 7    14.0          8         440.0       215.0  4312.0           8.5
# 8    14.0          8         455.0       225.0  4425.0          10.0
# 9    15.0          8         390.0       190.0  3850.0           8.5
# 10   15.0          8         383.0       170.0  3563.0          10.0
# 11   14.0          8         340.0       160.0  3609.0           8.0
# 12   15.0          8         400.0       150.0  3761.0           9.5
# ...

# %% [markdown]
# # 5. The origin column values are 1, 2, and 3. Convert these values respectively to ‘USA’, ‘Asia’, and ‘Europe’

# %%
origin = {1: 'USA', 2: 'Asia',3: 'Europe'}
df.origin = df.origin.map(origin)
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# 5    15.0          8         429.0       198.0  4341.0          10.0
# 6    14.0          8         454.0       220.0  4354.0           9.0
# 7    14.0          8         440.0       215.0  4312.0           8.5
# 8    14.0          8         455.0       225.0  4425.0          10.0
# 9    15.0          8         390.0       190.0  3850.0           8.5
# 10   15.0          8         383.0       170.0  3563.0          10.0
# 11   14.0          8         340.0       160.0  3609.0           8.0
# 12   15.0          8         400.0       150.0  3761.0           9.5
# ...

# %% [markdown]
# # 6. Create a bar chart that shows the distribution for cylinders.

# %%
bar_chart = sns.countplot(x="cylinders", hue='origin' ,data=df)
plt.xlabel('Cylinders',size=20)
plt.ylabel('Frequency')
plt.suptitle('Distribution of cylinders')
# Out:
# Text(0.5,0.98,'Distribution of cylinders')

# %% [markdown]
# # 7. Create a scatterplot that shows the relationship between horsepower and weight.

# %%
scatterplot = sns.lmplot(x="horsepower", y="weight", data=df)
plt.xlabel("Horsepower")
plt.ylabel("Weight")
plt.suptitle('Relationship between Horsepower and Weight')
# Out:
# Text(0.5,0.98,'Relationship between Horsepower and Weight')

# %%
scatterplot = sns.lmplot(x="horsepower", y="weight", data=df,hue="origin")
plt.xlabel("Horsepower")
plt.ylabel("Weight")
plt.suptitle('Relationship between Horsepower and Weight origin wise')
# Out:
# Text(0.5,0.98,'Relationship between Horsepower and Weight origin wise')

# %% [markdown]
# # 8. Ask, then answeran interesting question about the distribution of one of the variables, or the relationship between two (or more!) of the variables in the “Auto MPG” dataset.

# %%
scatterplot = sns.lmplot(x="model_year", y="mpg", data=df,hue="origin")
plt.xlabel("Model Year")
plt.ylabel("MPG")
plt.suptitle('MPG over year origin based')
# Out:
# Text(0.5,0.98,'MPG over year origin based')
